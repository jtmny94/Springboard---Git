# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
# Load the pyplot collection of functions from matplotlib, as plt 

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls
# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# Receive "HTTPError: HTTP Error 403: Forbidden" Error when using link; pd.read_excel executed on the file itself:

properties = pd.read_excel('UK House price index.xlsx', sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          90347              51870      98948      64956
# 2 1995-02-01          81213              52513      98848      64786
# 3 1995-03-01          78168              52701      97848      64366
# 4 1995-04-01          76172              54618      96273      64276
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1      76880      83082     119775      70118      85469  ...      40907
# 2      77651      83068     118365      69908      86551  ...      40877
# 3      77644      82856     119131      69666      87067  ...      41351
# 4      78668      82525     118948      69562      87933  ...      41195
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
properties.shape
# Out:
# (363, 49)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.index
# Out:
# RangeIndex(start=0, stop=363, step=1)

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties = properties.drop('Unnamed: 47', axis=1)

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          90347              51870      98948      64956
# 2 1995-02-01          81213              52513      98848      64786
# 3 1995-03-01          78168              52701      97848      64366
# 4 1995-04-01          76172              54618      96273      64276
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH EAST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000001
# 1      76880      83082     119775      70118      85469  ...      39809
# 2      77651      83068     118365      69908      86551  ...      40278
# 3      77644      82856     119131      69666      87067  ...      40086
# 4      78668      82525     118948      69562      87933  ...      39827
#
#   NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties_t = properties.transpose()
properties_t.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                90347                81213
# Barking & Dagenham  E09000002                51870                52513
# Barnet              E09000003                98948                98848
# Bexley              E09000004                64956                64786
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                    78168                76172
# Barking & Dagenham                52701                54618
# Barnet                            97848                96273
# Bexley                            64366                64276
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_t = properties_t.reset_index()
properties_t.index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
properties_t.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                90347                81213
# 2  Barking & Dagenham  E09000002                51870                52513
# 3              Barnet  E09000003                98948                98848
# 4              Bexley  E09000004                64956                64786
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1                78168                76172                83392
# 2                52701                54618                54524
# 3                97848                96273                95737
# 4                64366                64276                63995
#
#                      6                    7                    8  ...  \
# ...

# %%
properties_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            353,     354,     355,     356,     357,     358,     359,     360,
#            361,     362],
#       dtype='object', length=364)

# %%
properties_t.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    353                  354                  355  \
# 0  2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
#
#                    356                  357                  358  \
# 0  2024-08-01 00:00:00  2024-09-01 00:00:00  2024-10-01 00:00:00
#
#                    359                  360                  361  \
# 0  2024-11-01 00:00:00  2024-12-01 00:00:00  2025-01-01 00:00:00
#
#                    362
# 0  2025-02-01 00:00:00
#
# [1 rows x 364 columns]

# %%
properties_t.columns = properties_t.iloc[0]
properties_t.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                90347                81213
# 2  Barking & Dagenham  E09000002                51870                52513
# 3              Barnet  E09000003                98948                98848
# 4              Bexley  E09000004                64956                64786
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1                78168                76172                83392
# 2                52701                54618                54524
# 3                97848                96273                95737
# 4                64366                64276                63995
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_t = properties_t.drop(0, axis=0)
properties_t.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               90347               81213
# 2  Barking & Dagenham  E09000002               51870               52513
# 3              Barnet  E09000003               98948               98848
# 4              Bexley  E09000004               64956               64786
# 5               Brent  E09000005               76880               77651
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1               78168               76172               83392
# 2               52701               54618               54524
# 3               97848               96273               95737
# 4               64366               64276               63995
# 5               77644               78668               79464
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1               93757              108801              110976  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_t = properties_t.rename(columns={'Unnamed: 0': 'London Boroughs', pd.NaT:'ID'})
properties_t.head()
# Out:
# 0     London Boroughs         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               90347               81213
# 2  Barking & Dagenham  E09000002               51870               52513
# 3              Barnet  E09000003               98948               98848
# 4              Bexley  E09000004               64956               64786
# 5               Brent  E09000005               76880               77651
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1               78168               76172               83392
# 2               52701               54618               54524
# 3               97848               96273               95737
# 4               64366               64276               63995
# 5               77644               78668               79464
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1               93757              108801              110976  ...
# ...

# %%
properties_t.to_csv('properties_t')

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_clean = pd.melt(properties_t, id_vars=['London Boroughs', 'ID'])
properties_clean.head()
# Out:
#       London Boroughs         ID                    0  value
# 0      City of London  E09000001  1995-01-01 00:00:00  90347
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00  51870
# 2              Barnet  E09000003  1995-01-01 00:00:00  98948
# 3              Bexley  E09000004  1995-01-01 00:00:00  64956
# 4               Brent  E09000005  1995-01-01 00:00:00  76880

# %%
properties_clean = properties_clean.rename(columns={'value':'avg_housing_price'})
properties_clean.head()
# Out:
#       London Boroughs         ID                    0 avg_housing_price
# 0      City of London  E09000001  1995-01-01 00:00:00             90347
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00             51870
# 2              Barnet  E09000003  1995-01-01 00:00:00             98948
# 3              Bexley  E09000004  1995-01-01 00:00:00             64956
# 4               Brent  E09000005  1995-01-01 00:00:00             76880

# %%
properties_clean.iloc[:,2]
# Out:
# 0        1995-01-01 00:00:00
# 1        1995-01-01 00:00:00
# 2        1995-01-01 00:00:00
# 3        1995-01-01 00:00:00
# 4        1995-01-01 00:00:00
#                 ...
# 17009    2025-02-01 00:00:00
# 17010    2025-02-01 00:00:00
# 17011    2025-02-01 00:00:00
# 17012    2025-02-01 00:00:00
# 17013    2025-02-01 00:00:00
# Name: 0, Length: 17014, dtype: object

# %%
properties_clean['year_month'] = properties_clean.iloc[:,2]

# %%
properties_clean.head()
# Out:
#       London Boroughs         ID                    0 avg_housing_price  \
# 0      City of London  E09000001  1995-01-01 00:00:00             90347
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00             51870
# 2              Barnet  E09000003  1995-01-01 00:00:00             98948
# 3              Bexley  E09000004  1995-01-01 00:00:00             64956
# 4               Brent  E09000005  1995-01-01 00:00:00             76880
#
#             year_month
# 0  1995-01-01 00:00:00
# 1  1995-01-01 00:00:00
# 2  1995-01-01 00:00:00
# 3  1995-01-01 00:00:00
# 4  1995-01-01 00:00:00

# %%
properties_clean.drop(properties_clean.columns[2], axis=1, inplace=True)
properties_clean.head()
# Out:
#       London Boroughs         ID avg_housing_price           year_month
# 0      City of London  E09000001             90347  1995-01-01 00:00:00
# 1  Barking & Dagenham  E09000002             51870  1995-01-01 00:00:00
# 2              Barnet  E09000003             98948  1995-01-01 00:00:00
# 3              Bexley  E09000004             64956  1995-01-01 00:00:00
# 4               Brent  E09000005             76880  1995-01-01 00:00:00

# %%
print(properties_clean['avg_housing_price'].dtypes)
# Out:
# object

# %%
properties_clean['avg_housing_price'] = properties_clean.avg_housing_price.astype(float)
properties_clean['avg_housing_price'].dtype
# Out:
# dtype('float64')

# %%
properties_clean.to_excel('properties_clean.xlsx', sheet_name='Sheet1', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
properties_clean = pd.read_excel('properties_clean.xlsx', sheet_name='Sheet1')
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month
# 0      City of London  E09000001            90347.0 1995-01-01
# 1  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 2              Barnet  E09000003            98948.0 1995-01-01
# 3              Bexley  E09000004            64956.0 1995-01-01
# 4               Brent  E09000005            76880.0 1995-01-01

# %%
properties_clean['year_month'].dtype
# Out:
# dtype('<M8[ns]')

# %%
properties_clean['year_month'] = pd.to_datetime(properties_clean['year_month'])

# %%
properties_clean['year_month'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month
# 0      City of London  E09000001            90347.0 1995-01-01
# 1  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 2              Barnet  E09000003            98948.0 1995-01-01
# 3              Bexley  E09000004            64956.0 1995-01-01
# 4               Brent  E09000005            76880.0 1995-01-01

# %%
properties_clean[properties_clean['ID'].isnull()]
# Out:
#       London Boroughs   ID  avg_housing_price year_month
# 33        Unnamed: 34  NaN                NaN 1995-01-01
# 36        Unnamed: 37  NaN                NaN 1995-01-01
# 80        Unnamed: 34  NaN                NaN 1995-02-01
# 83        Unnamed: 37  NaN                NaN 1995-02-01
# 127       Unnamed: 34  NaN                NaN 1995-03-01
# ...               ...  ...                ...        ...
# 16909     Unnamed: 37  NaN                NaN 2024-12-01
# 16953     Unnamed: 34  NaN                NaN 2025-01-01
# 16956     Unnamed: 37  NaN                NaN 2025-01-01
# 17000     Unnamed: 34  NaN                NaN 2025-02-01
# 17003     Unnamed: 37  NaN                NaN 2025-02-01
#
# [724 rows x 4 columns]

# %%
properties_clean = properties_clean.dropna()
properties_clean.shape
# Out:
# (16290, 4)

# %%
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month
# 0      City of London  E09000001            90347.0 1995-01-01
# 1  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 2              Barnet  E09000003            98948.0 1995-01-01
# 3              Bexley  E09000004            64956.0 1995-01-01
# 4               Brent  E09000005            76880.0 1995-01-01

# %%
properties_clean[properties_clean['ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [London Boroughs, ID, avg_housing_price, year_month]
# Index: []

# %%
properties_clean['London Boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
properties_clean['London Boroughs'].nunique()
# Out:
# 45

# %%
properties_clean['ID'].unique()
# Out:
# array(['E09000001', 'E09000002', 'E09000003', 'E09000004', 'E09000005',
#        'E09000006', 'E09000007', 'E09000008', 'E09000009', 'E09000010',
#        'E09000011', 'E09000012', 'E09000013', 'E09000014', 'E09000015',
#        'E09000016', 'E09000017', 'E09000018', 'E09000019', 'E09000020',
#        'E09000021', 'E09000022', 'E09000023', 'E09000024', 'E09000025',
#        'E09000026', 'E09000027', 'E09000028', 'E09000029', 'E09000030',
#        'E09000031', 'E09000032', 'E09000033', 'E13000001', 'E13000002',
#        'E12000001', 'E12000002', 'E12000003', 'E12000004', 'E12000005',
#        'E12000006', 'E12000007', 'E12000008', 'E12000009', 'E92000001'],
#       dtype=object)

# %%
properties_clean.to_excel('properties_clean.xlsx', sheet_name='Sheet1', index=False)

# %%
boroughs = {'boroughs':['Westminster','Camden','Islington','Lambeth','Southwark','Tower Hamlets','Hackney','Hammersmith & Fulham',
            'Haringey','Kensington & Chelsea','Wandsworth','Barking & Dagenham','Barnet','Bexley','Brent','Bromley','Croydon',
            'Ealing','Enfield','Greenwich','Harrow','Havering','Hillingdon','Hounslow','Kingston upon Thames','Merton','Newham','Redbridge',
            'Richmond upon Thames','Sutton','Waltham Forest','Lewisham']}

# %%
london_boroughs = pd.DataFrame(boroughs)
london_boroughs.head()
# Out:
#       boroughs
# 0  Westminster
# 1       Camden
# 2    Islington
# 3      Lambeth
# 4    Southwark

# %%
london_boroughs.nunique()
# Out:
# boroughs    32
# dtype: int64

# %%
test = properties_clean.merge(london_boroughs, left_on='London Boroughs', right_on='boroughs')
test.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  \
# 0  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 1              Barnet  E09000003            98948.0 1995-01-01
# 2              Bexley  E09000004            64956.0 1995-01-01
# 3               Brent  E09000005            76880.0 1995-01-01
# 4             Bromley  E09000006            83082.0 1995-01-01
#
#              boroughs
# 0  Barking & Dagenham
# 1              Barnet
# 2              Bexley
# 3               Brent
# 4             Bromley

# %%
test = properties_clean.merge(london_boroughs, left_on='London Boroughs', right_on='boroughs', how='outer')
test.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  \
# 0  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 1  Barking & Dagenham  E09000002            52513.0 1995-02-01
# 2  Barking & Dagenham  E09000002            52701.0 1995-03-01
# 3  Barking & Dagenham  E09000002            54618.0 1995-04-01
# 4  Barking & Dagenham  E09000002            54524.0 1995-05-01
#
#              boroughs
# 0  Barking & Dagenham
# 1  Barking & Dagenham
# 2  Barking & Dagenham
# 3  Barking & Dagenham
# 4  Barking & Dagenham

# %%
test[test['boroughs'].isnull()]
# Out:
#           London Boroughs         ID  avg_housing_price year_month boroughs
# 2172       City of London  E09000001            90347.0 1995-01-01      NaN
# 2173       City of London  E09000001            81213.0 1995-02-01      NaN
# 2174       City of London  E09000001            78168.0 1995-03-01      NaN
# 2175       City of London  E09000001            76172.0 1995-04-01      NaN
# 2176       City of London  E09000001            83392.0 1995-05-01      NaN
# ...                   ...        ...                ...        ...      ...
# 16285  YORKS & THE HUMBER  E12000003           202212.0 2024-10-01      NaN
# 16286  YORKS & THE HUMBER  E12000003           204616.0 2024-11-01      NaN
# 16287  YORKS & THE HUMBER  E12000003           204123.0 2024-12-01      NaN
# 16288  YORKS & THE HUMBER  E12000003           202277.0 2025-01-01      NaN
# 16289  YORKS & THE HUMBER  E12000003           205455.0 2025-02-01      NaN
#
# [4706 rows x 5 columns]

# %%
test['London Boroughs'].nunique()
# Out:
# 45

# %%
test = test.dropna()
test['London Boroughs'].nunique()
# Out:
# 32

# %%
properties_clean = test

# %%
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  \
# 0  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 1  Barking & Dagenham  E09000002            52513.0 1995-02-01
# 2  Barking & Dagenham  E09000002            52701.0 1995-03-01
# 3  Barking & Dagenham  E09000002            54618.0 1995-04-01
# 4  Barking & Dagenham  E09000002            54524.0 1995-05-01
#
#              boroughs
# 0  Barking & Dagenham
# 1  Barking & Dagenham
# 2  Barking & Dagenham
# 3  Barking & Dagenham
# 4  Barking & Dagenham

# %%
properties_clean.to_excel('properties_clean.xlsx', sheet_name='Sheet1', index=False)

# %%
properties_clean = properties_clean.drop('boroughs', axis=1)
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month
# 0  Barking & Dagenham  E09000002            51870.0 1995-01-01
# 1  Barking & Dagenham  E09000002            52513.0 1995-02-01
# 2  Barking & Dagenham  E09000002            52701.0 1995-03-01
# 3  Barking & Dagenham  E09000002            54618.0 1995-04-01
# 4  Barking & Dagenham  E09000002            54524.0 1995-05-01

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
properties_clean.plot(x='year_month', y='avg_housing_price', kind='line')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties_clean.to_excel('properties_clean.xlsx', sheet_name='Sheet1', index=False)

# %%
properties_clean['year'] = properties_clean['year_month'].dt.year
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  year
# 0  Barking & Dagenham  E09000002            51870.0 1995-01-01  1995
# 1  Barking & Dagenham  E09000002            52513.0 1995-02-01  1995
# 2  Barking & Dagenham  E09000002            52701.0 1995-03-01  1995
# 3  Barking & Dagenham  E09000002            54618.0 1995-04-01  1995
# 4  Barking & Dagenham  E09000002            54524.0 1995-05-01  1995

# %%
properties_clean.plot(x='year', y='avg_housing_price', kind='line')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

properties_clean = pd.read_excel('properties_clean.xlsx', sheet_name='Sheet1')
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  year
# 0  Barking & Dagenham  E09000002              51870 1995-01-01  1995
# 1  Barking & Dagenham  E09000002              52513 1995-02-01  1995
# 2  Barking & Dagenham  E09000002              52701 1995-03-01  1995
# 3  Barking & Dagenham  E09000002              54618 1995-04-01  1995
# 4  Barking & Dagenham  E09000002              54524 1995-05-01  1995

# %%
properties_clean['year'] = properties_clean['year_month'].dt.year
properties_clean.to_excel('properties_clean.xlsx', sheet_name='Sheet1', index=False)

# %%
properties_clean.head()
# Out:
#       London Boroughs         ID  avg_housing_price year_month  year
# 0  Barking & Dagenham  E09000002              51870 1995-01-01  1995
# 1  Barking & Dagenham  E09000002              52513 1995-02-01  1995
# 2  Barking & Dagenham  E09000002              52701 1995-03-01  1995
# 3  Barking & Dagenham  E09000002              54618 1995-04-01  1995
# 4  Barking & Dagenham  E09000002              54524 1995-05-01  1995

# %%
properties_clean['year'].dtype
# Out:
# dtype('int32')

# %%
mean_property = properties_clean.groupby(by=['London Boroughs', 'year']).mean(numeric_only=True).reset_index()

# %%
mean_property.head()
# Out:
#       London Boroughs  year  avg_housing_price
# 0  Barking & Dagenham  1995       53265.416667
# 1  Barking & Dagenham  1996       53162.666667
# 2  Barking & Dagenham  1997       57537.583333
# 3  Barking & Dagenham  1998       61969.666667
# 4  Barking & Dagenham  1999       67145.333333

# %%
mean_property['avg_housing_price'].dtype
# Out:
# dtype('float64')

# %%
mean_property.index
# Out:
# RangeIndex(start=0, stop=992, step=1)

# %%
mean_property.columns
# Out:
# Index(['London Boroughs', 'year', 'avg_housing_price'], dtype='object')

# %%
mean_property.to_excel('mean_property.xlsx', sheet_name='Sheet1', index=False)

# %%
mean_property.head()
# Out:
#       London Boroughs  year  avg_housing_price
# 0  Barking & Dagenham  1995       53265.416667
# 1  Barking & Dagenham  1996       53162.666667
# 2  Barking & Dagenham  1997       57537.583333
# 3  Barking & Dagenham  1998       61969.666667
# 4  Barking & Dagenham  1999       67145.333333

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(df):
    y1995 = float(df['avg_housing_price'][df['year']==1995])
    y2025 = float(df['avg_housing_price'][df['year']==2025])
    ratio = [y2025/y1995]
    return ratio

# %%
create_price_ratio(mean_property[mean_property['London Boroughs']=='Camden'])
# Out:
# /var/folders/jq/gj1vx0fx53zb4s13cry38xs80000gp/T/ipykernel_945/834773008.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y1995 = float(df['avg_housing_price'][df['year']==1995])
# /var/folders/jq/gj1vx0fx53zb4s13cry38xs80000gp/T/ipykernel_945/834773008.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y2025 = float(df['avg_housing_price'][df['year']==2025])
# [6.912220978749194]

# %%
final = {}

# %%
for b in mean_property['London Boroughs'].unique():
    borough = mean_property[mean_property['London Boroughs'] == b]
    final[b] = create_price_ratio(borough)
# Out:
# /var/folders/jq/gj1vx0fx53zb4s13cry38xs80000gp/T/ipykernel_945/834773008.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y1995 = float(df['avg_housing_price'][df['year']==1995])
# /var/folders/jq/gj1vx0fx53zb4s13cry38xs80000gp/T/ipykernel_945/834773008.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y2025 = float(df['avg_housing_price'][df['year']==2025])

# %%
print(final)
# Out:
# {'Barking & Dagenham': [6.726221672911598], 'Barnet': [6.233096909312973], 'Bexley': [6.329757076361317], 'Brent': [7.162084100210721], 'Bromley': [6.201216276315592], 'Camden': [6.912220978749194], 'Croydon': [5.903720319548939], 'Ealing': [6.672731457506186], 'Enfield': [6.1997065799340785], 'Greenwich': [7.084171210876224], 'Hackney': [8.870256591179045], 'Hammersmith & Fulham': [5.903622654271457], 'Haringey': [7.413750403008354], 'Harrow': [6.266073260444743], 'Havering': [6.381642506265182], 'Hillingdon': [6.294972118672787], 'Hounslow': [6.360876072760631], 'Islington': [6.900356628656489], 'Kensington & Chelsea': [5.71063973214571], 'Kingston upon Thames': [6.64913187198371], 'Lambeth': [7.794643255148892], 'Lewisham': [7.973601136295437], 'Merton': [7.1378248457358], 'Newham': [7.292118016380122], 'Redbridge': [6.904579670843464], 'Richmond upon Thames': [6.776396916115335], 'Southwark': [7.861486900218302], 'Sutton': [6.294406612105228], 'Tower Hamlets': [7.2011807079477155
# ...

# %%
property_ratios = pd.DataFrame(final)
property_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            6.726222  6.233097  6.329757  7.162084  6.201216  6.912221
#
#    Croydon    Ealing   Enfield  Greenwich  ...    Merton    Newham  Redbridge  \
# 0  5.90372  6.672731  6.199707   7.084171  ...  7.137825  7.292118    6.90458
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              6.776397   7.861487  6.294407       7.201181        8.229226
#
#    Wandsworth  Westminster
# 0    6.935742     6.589996
#
# [1 rows x 32 columns]

# %%
property_ratios = property_ratios.T

# %%
property_ratios.head()
# Out:
#                            0
# Barking & Dagenham  6.726222
# Barnet              6.233097
# Bexley              6.329757
# Brent               7.162084
# Bromley             6.201216

# %%
property_ratios.reset_index()
# Out:
#                    index         0
# 0     Barking & Dagenham  6.726222
# 1                 Barnet  6.233097
# 2                 Bexley  6.329757
# 3                  Brent  7.162084
# 4                Bromley  6.201216
# 5                 Camden  6.912221
# 6                Croydon  5.903720
# 7                 Ealing  6.672731
# 8                Enfield  6.199707
# 9              Greenwich  7.084171
# 10               Hackney  8.870257
# 11  Hammersmith & Fulham  5.903623
# 12              Haringey  7.413750
# 13                Harrow  6.266073
# 14              Havering  6.381643
# 15            Hillingdon  6.294972
# 16              Hounslow  6.360876
# 17             Islington  6.900357
# 18  Kensington & Chelsea  5.710640
# 19  Kingston upon Thames  6.649132
# 20               Lambeth  7.794643
# 21              Lewisham  7.973601
# 22                Merton  7.137825
# 23                Newham  7.292118
# 24             Redbridge  6.904580
# 25  Richmond upon Thames  6.776397
# ...

# %%
property_ratios.rename(columns={'index':'Borough', 0:'2025'}, inplace=True)

# %%
property_ratios.head()
# Out:
#                         2025
# Barking & Dagenham  6.726222
# Barnet              6.233097
# Bexley              6.329757
# Brent               7.162084
# Bromley             6.201216

# %%
property_ratios_sorted = property_ratios.sort_values(by='2025', ascending=False)

# %%
property_ratios_sorted.head()
# Out:
#                     2025
# Hackney         8.870257
# Waltham Forest  8.229226
# Lewisham        7.973601
# Southwark       7.861487
# Lambeth         7.794643

# %%
property_ratios_sorted.to_excel('property_ratios_sorted.xlsx', sheet_name='Sheet1', index=False)

# %%
print(property_ratios_sorted)
# Out:
#                           2025
# Hackney               8.870257
# Waltham Forest        8.229226
# Lewisham              7.973601
# Southwark             7.861487
# Lambeth               7.794643
# Haringey              7.413750
# Newham                7.292118
# Tower Hamlets         7.201181
# Brent                 7.162084
# Merton                7.137825
# Greenwich             7.084171
# Wandsworth            6.935742
# Camden                6.912221
# Redbridge             6.904580
# Islington             6.900357
# Richmond upon Thames  6.776397
# Barking & Dagenham    6.726222
# Ealing                6.672731
# Kingston upon Thames  6.649132
# Westminster           6.589996
# Havering              6.381643
# Hounslow              6.360876
# Bexley                6.329757
# Hillingdon            6.294972
# Sutton                6.294407
# Harrow                6.266073
# Barnet                6.233097
# Bromley               6.201216
# Enfield               6.199707
# ...

# %%
property_ratios_top5 = property_ratios_sorted[:5]
print(property_ratios_top5)
# Out:
#                     2025
# Hackney         8.870257
# Waltham Forest  8.229226
# Lewisham        7.973601
# Southwark       7.861487
# Lambeth         7.794643

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# _____________
# **Hackney is the London borough that has experienced the greatest average increase in housing prices over the last three decades (1995-2025).**
